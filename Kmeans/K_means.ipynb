# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Generate synthetic data
n_samples = 300
n_features = 2
n_clusters = 3
random_state = 42

X, _ = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=random_state)

# Create and fit a K-means clustering model
kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
kmeans.fit(X)

# Predict cluster labels for each data point
labels = kmeans.labels_

# Get cluster centers
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='x', s=200, linewidths=3, color='r')
plt.title('K-means Clustering')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
n_samples = 300
n_features = 2
n_clusters = 3
random_state = 42

X, y = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=random_state)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %% [markdown]
# #normal process
# ##Elbow Method to select the k values

# %%
wcss = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++')  # Use 'k-means++' with lowercase 'k'
    kmeans.fit(X_train)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [13387.301827652005,
#  3939.2897981523147,
#  401.90441408462084,
#  347.878679046079,
#  297.60081263590007,
#  250.50931137404734,
#  221.347925083037,
#  191.1690648415774,
#  172.8810864588482,
#  151.9173987548205]

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++')

# %%
y_labels=kmeans.fit_predict(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=y_labels)

# %%
y_test_labels=kmeans.predict(X_test)

# %%
plt.scatter(X_test[:,0],X_test[:,1],c=y_test_labels)

# %% [markdown]
# #knee locator

# %%
# !pip install kneed

# %%
from kneed import KneeLocator

# %%
kl=KneeLocator(range(1,11),wcss,curve='convex',direction='decreasing')#concave veram

# %%
kl.elbow
# Out:
# 3

# %% [markdown]
# ## performance metrics

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_coefficients = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++')  # Use 'k-means++' with lowercase 'k'
    kmeans.fit(X_train)
    score=silhouette_score(X_train,kmeans.labels_)
    silhouette_coefficients.append(score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
silhouette_coefficients
# Out:
# [0.6984688953242009,
#  0.8404076983981034,
#  0.6942140065031968,
#  0.5122309383269277,
#  0.3437712903394587,
#  0.3493772768572142,
#  0.3580273982681035,
#  0.3609277813016784,
#  0.3667249269372765]

# %%
plt.plot(range(2,11),silhouette_coefficients)
plt.xticks(range(2,11))
plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np

# Sample data
data = np.array([[1, 2], [5, 8], [1.5, 1.8], [8, 8], [1, 0.6], [9, 11]])

# Initialize K-means with K-means++ initialization
kmeans = KMeans(n_clusters=2, init='k-means++')

# Fit the model to the data
kmeans.fit(data)

# Get cluster centroids
centroids = kmeans.cluster_centers_

# Get cluster labels for each data point
labels = kmeans.labels_

print("Centroids:", centroids)
print("Cluster Labels:", labels)
# Out:
# Centroids: [[7.33333333 9.        ]
#  [1.16666667 1.46666667]]
# Cluster Labels: [1 0 1 0 1 0]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Generate some sample data
np.random.seed(0)
X = np.random.randn(100, 5)  # 100 samples with 5 features

# Apply PCA to reduce dimensionality
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Create a K-means clustering model
kmeans = KMeans(n_clusters=3, random_state=0)

# Fit K-means to the reduced data
kmeans.fit(X_pca)

# Predict cluster labels
labels = kmeans.labels_

# Visualize the clusters
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering with PCA')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd
data = pd.read_csv('/content/income.csv')

# %%
data.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
data.shape
# Out:
# (22, 3)

# %%
data.drop(['Name'],axis=1,inplace=True)
data
# Out:
#     Age  Income($)
# 0    27      70000
# 1    29      90000
# 2    29      61000
# 3    28      60000
# 4    42     150000
# 5    39     155000
# 6    41     160000
# 7    38     162000
# 8    36     156000
# 9    35     130000
# 10   37     137000
# 11   26      45000
# 12   27      48000
# 13   28      51000
# 14   29      49500
# 15   32      53000
# 16   40      65000
# 17   41      63000
# 18   43      64000
# 19   39      80000
# 20   41      82000
# 21   39      58000

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
s = MinMaxScaler()
data['Age']=s.fit_transform(data[['Age']])
data
# Out:
#          Age  Income($)
# 0   0.058824      70000
# 1   0.176471      90000
# 2   0.176471      61000
# 3   0.117647      60000
# 4   0.941176     150000
# 5   0.764706     155000
# 6   0.882353     160000
# 7   0.705882     162000
# 8   0.588235     156000
# 9   0.529412     130000
# 10  0.647059     137000
# 11  0.000000      45000
# 12  0.058824      48000
# 13  0.117647      51000
# 14  0.176471      49500
# 15  0.352941      53000
# 16  0.823529      65000
# 17  0.882353      63000
# 18  1.000000      64000
# 19  0.764706      80000
# 20  0.882353      82000
# 21  0.764706      58000

# %%
data['Income($)']=s.fit_transform(data[['Income($)']])
data
# Out:
#          Age  Income($)
# 0   0.058824   0.213675
# 1   0.176471   0.384615
# 2   0.176471   0.136752
# 3   0.117647   0.128205
# 4   0.941176   0.897436
# 5   0.764706   0.940171
# 6   0.882353   0.982906
# 7   0.705882   1.000000
# 8   0.588235   0.948718
# 9   0.529412   0.726496
# 10  0.647059   0.786325
# 11  0.000000   0.000000
# 12  0.058824   0.025641
# 13  0.117647   0.051282
# 14  0.176471   0.038462
# 15  0.352941   0.068376
# 16  0.823529   0.170940
# 17  0.882353   0.153846
# 18  1.000000   0.162393
# 19  0.764706   0.299145
# 20  0.882353   0.316239
# 21  0.764706   0.111111

# %%
sse = np.array([])

# %%
from sklearn.cluster import KMeans

# %%
for i in range(1,len(data['Age'])):
  model=KMeans(n_clusters=i)
  model.fit(data)
  sse=np.append(sse, model.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
sse
# Out:
# array([5.43401151e+00, 2.09113639e+00, 4.75078350e-01, 3.49104709e-01,
#        2.66403012e-01, 2.10554790e-01, 1.68585122e-01, 1.32766193e-01,
#        1.03837526e-01, 7.99693743e-02, 6.55400581e-02, 4.68116843e-02,
#        3.81015109e-02, 3.11579670e-02, 2.50438814e-02, 1.64164911e-02,
#        1.10338195e-02, 7.51395749e-03, 5.45512258e-03, 3.57891606e-03,
#        1.76662948e-03])

# %%
sse_dict={x:y for x,y in enumerate(sse)}
sse_dict
# Out:
# {0: 5.434011511988178,
#  1: 2.091136388699078,
#  2: 0.4750783498553096,
#  3: 0.3491047094419566,
#  4: 0.26640301246684156,
#  5: 0.21055478995472496,
#  6: 0.1685851223602976,
#  7: 0.1327661931978319,
#  8: 0.1038375258660356,
#  9: 0.07996937425152906,
#  10: 0.06554005805181391,
#  11: 0.046811684349391744,
#  12: 0.038101510924463636,
#  13: 0.03115796698331521,
#  14: 0.025043881367632585,
#  15: 0.01641649105272562,
#  16: 0.011033819491365383,
#  17: 0.00751395748512241,
#  18: 0.0054551225809321684,
#  19: 0.003578916064498534,
#  20: 0.0017666294837796928}

# %%
import seaborn as sns
sns.scatterplot(x=sse_dict.keys(),y=sse_dict.values())
# Out:
# <Axes: >

# %%
model=KMeans(n_clusters=3)
kmeans=model.fit(data[["Age",'Income($)']])
data['clusters']=kmeans.labels_
data
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          Age  Income($)  clusters
# 0   0.058824   0.213675         1
# 1   0.176471   0.384615         1
# 2   0.176471   0.136752         1
# 3   0.117647   0.128205         1
# 4   0.941176   0.897436         0
# 5   0.764706   0.940171         0
# 6   0.882353   0.982906         0
# 7   0.705882   1.000000         0
# 8   0.588235   0.948718         0
# 9   0.529412   0.726496         0
# 10  0.647059   0.786325         0
# 11  0.000000   0.000000         1
# 12  0.058824   0.025641         1
# 13  0.117647   0.051282         1
# 14  0.176471   0.038462         1
# 15  0.352941   0.068376         1
# 16  0.823529   0.170940         2
# 17  0.882353   0.153846         2
# 18  1.000000   0.162393         2
# 19  0.764706   0.299145         2
# ...

# %%
sns.scatterplot(x=kmeans.cluster_centers_[:,0],
                y=kmeans.cluster_centers_[:,1])
# Out:
# <Axes: >

# %%
sns.scatterplot(x="Age",y='Income($)',data=data,hue='clusters')
# Out:
# <Axes: xlabel='Age', ylabel='Income($)'>

# %%
sns.scatterplot(x=kmeans.cluster_centers_[:,0],
                y=kmeans.cluster_centers_[:,1])
sns.scatterplot(x="Age",y='Income($)',data=data,hue='clusters')
# Out:
# <Axes: xlabel='Age', ylabel='Income($)'>

# %%
kmeans.cluster_centers_#shape (3, 2)
# Out:
# array([[0.72268908, 0.8974359 ],
#        [0.1372549 , 0.11633428],
#        [0.85294118, 0.2022792 ]])

# %%
for i, center in enumerate(cluster_centers):
    print(f"Cluster {i + 1} Center: (Age={center[0]}, Income($)={center[1]})")
# Out:
# Cluster 1 Center: (Age=4.747103374180735, Income($)=2.0105942727713373)
# Cluster 2 Center: (Age=-6.883871789341752, Income($)=-6.9839841467131265)
# Cluster 3 Center: (Age=-2.633232678649361, Income($)=9.043569782044543)
